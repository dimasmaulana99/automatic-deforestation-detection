# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from PIL import Image
import keras
from keras.models import Model
from keras.layers import Conv2D, MaxPooling2D, Input, Conv2DTranspose, Concatenate, BatchNormalization, UpSampling2D
from keras.layers import  Dropout, Activation
from tensorflow.keras.optimizers import Adam, SGD
from keras.layers import LeakyReLU
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from keras import backend as K
from keras.utils.vis_utils import plot_model
import tensorflow as tf
import glob
import random
import cv2
from random import shuffle
from osgeo import gdal

from pyproj import Proj, transform
from tqdm import tqdm
from shapely.geometry import Polygon

# %%
import os
import numpy as np
import cv2
from glob import glob
import tensorflow as tf
from sklearn.model_selection import train_test_split

path = "E:\\UNet\\Tiles\\Merge" 
images = sorted(glob(os.path.join(path, "image/*")))
masks = sorted(glob(os.path.join(path, "mask/*")))

minx = -70
maxx = 70

a = images[1]
b = gdal.Open(a).ReadAsArray()
c = np.rollaxis(b, 0, 3)
d = (c - minx) / (maxx - minx)

e = masks[1]
f = gdal.Open(e).ReadAsArray()
g = np.expand_dims(f, axis=2)
g.shape
#h = (g - minx) / (maxx - minx)
# Out:
# (128, 128, 1)

# %%
def load_data(path, split=0.1):
    images = sorted(glob(os.path.join(path, "image/*")))
    masks = sorted(glob(os.path.join(path, "mask/*")))

    total_size = len(images)
    valid_size = int(split * total_size)
    test_size = int(split * total_size)

    train_x, valid_x = train_test_split(images, test_size=valid_size, random_state=42)
    train_y, valid_y = train_test_split(masks, test_size=valid_size, random_state=42)

    train_x, test_x = train_test_split(train_x, test_size=test_size, random_state=42)
    train_y, test_y = train_test_split(train_y, test_size=test_size, random_state=42)

    return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)

# %%
def read_image(path):
    path = path.decode()
    x = gdal.Open(path).ReadAsArray()
    x = np.rollaxis(x, 0, 3)
    x = (x - minx) / (maxx - minx)
    x = x.astype(np.float32)
    return x

# %%
def read_mask(path):
    path = path.decode()
    x = gdal.Open(path).ReadAsArray()
    #x = np.rollaxis(x, 0, 3)
    x = np.expand_dims(x, axis=-1)
    x = x.astype(np.float32)
    return x

# %%
def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([128, 128, 5])
    y.set_shape([128, 128, 1])
    return x, y

# %%
def tf_dataset(x, y, batch=32):
    dataset = tf.data.Dataset.from_tensor_slices((x, y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.repeat()
    return dataset

# %%
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model

def conv_block(x, num_filters):
    x = Conv2D(num_filters, (3, 3), padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, (3, 3), padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def build_model():
    size = 128
    num_filters = [16, 32, 48, 64]
    inputs = Input((size, size, 5))

    skip_x = []
    x = inputs

    ## Encoder
    for f in num_filters:
        x = conv_block(x, f)
        skip_x.append(x)
        x = MaxPool2D((2, 2))(x)

    ## Bridge
    x = conv_block(x, num_filters[-1])

    num_filters.reverse()
    skip_x.reverse()

    ## Decoder
    for i, f in enumerate(num_filters):
        x = UpSampling2D((2, 2))(x)
        xs = skip_x[i]
        x = Concatenate()([x, xs])
        x = conv_block(x, f)

    ## Output
    x = Conv2D(1, (1, 1), padding="same")(x)
    x = Activation("sigmoid")(x)

    return Model(inputs, x)

# %%
import os
import numpy as np
import cv2
from glob import glob
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, CSVLogger, TensorBoard

# %%
def iou(y_true, y_pred):
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)

# %%
if __name__ == "__main__":
    ## Dataset
    path = "E:\\UNet\\Tiles\\Merge" 
    (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_data(path)

# %%
batch = 32
epochs = 100

# %%
train_dataset = tf_dataset(train_x, train_y, batch=batch)
valid_dataset = tf_dataset(valid_x, valid_y, batch=batch)
print(train_dataset)
print(valid_dataset)
# Out:
# <RepeatDataset element_spec=(TensorSpec(shape=(None, 128, 128, 5), dtype=tf.float32, name=None), TensorSpec(shape=(None, 128, 128, 1), dtype=tf.float32, name=None))>
# <RepeatDataset element_spec=(TensorSpec(shape=(None, 128, 128, 5), dtype=tf.float32, name=None), TensorSpec(shape=(None, 128, 128, 1), dtype=tf.float32, name=None))>

# %%
model = build_model()
opt = tf.keras.optimizers.Adam()
metrics = ["accuracy", tf.keras.metrics.Recall(), tf.keras.metrics.Precision(), iou]
model.compile(loss="binary_crossentropy", optimizer=opt, metrics=metrics)

# %%
callbacks = [
    ModelCheckpoint("files/model.h5"),
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=4),
    #CSVLogger("files/data.csv"),
    TensorBoard(),
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=False)
]

# %%
train_steps = len(train_x)//batch
valid_steps = len(valid_x)//batch

if len(train_x) % batch != 0:
    train_steps += 1
if len(valid_x) % batch != 0:
    valid_steps += 1

# %%
history = model.fit(train_dataset,
          validation_data=valid_dataset,
          epochs=epochs,
          steps_per_epoch=train_steps,
          validation_steps=valid_steps,
          callbacks=callbacks)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 12s 535ms/step - loss: 0.3764 - accuracy: 0.8650 - recall: 0.6799 - precision: 0.8952 - iou: 0.4087 - val_loss: 0.6554 - val_accuracy: 0.7823 - val_recall: 0.4925 - val_precision: 0.6607 - val_iou: 0.2396 - lr: 0.0010
# Epoch 2/100
# 11/11 [==============================] - 1s 121ms/step - loss: 0.2584 - accuracy: 0.9421 - recall: 0.9382 - precision: 0.8954 - iou: 0.5284 - val_loss: 0.5855 - val_accuracy: 0.8124 - val_recall: 0.5532 - val_precision: 0.7262 - val_iou: 0.2685 - lr: 0.0010
# Epoch 3/100
# 11/11 [==============================] - 1s 121ms/step - loss: 0.2373 - accuracy: 0.9461 - recall: 0.9473 - precision: 0.8986 - iou: 0.5567 - val_loss: 0.5327 - val_accuracy: 0.8035 - val_recall: 0.8625 - val_precision: 0.6111 - val_iou: 0.3458 - lr: 0.0010
# Epoch 4/100
# 11/11 [==============================] - 1s 121ms/step - loss: 0.2208 - accuracy: 0.9508 - recall: 0.9492 - precision: 0.9091 - iou: 0.5811 - val_loss: 0.4568 - val_accuracy: 0.8270 - val_recall: 0.9593 - val_precision: 0.6299 - val_iou: 0.3959 - lr: 0.0010
# Epoch 5/100
# 11/11 [==============================] - 1s 125ms/step - loss: 0.2041 - accuracy: 0.9551 - recall: 0.9482 - precision: 0.9213 - iou: 0.6052 - val_loss: 0.5101 - val_accuracy: 0.7373 - val_recall: 0.9933 - val_precision: 0.5216 - val_iou: 0.4175 - lr: 0.0010
# Epoch 6/100
# 11/11 [==============================] - 1s 123ms/step - loss: 0.1892 - accuracy: 0.9578 - recall: 0.9576 - precision: 0.9206 - iou: 0.6290 - val_loss: 0.5713 - val_accuracy: 0.6649 - val_recall: 0.9894 - val_precision: 0.4603 - val_iou: 0.3941 - lr: 0.0010
# Epoch 7/100
# 11/11 [==============================] - 1s 120ms/step - loss: 0.1767 - accuracy: 0.9602 - recall: 0.9577 - precision: 0.9270 - iou: 0.6494 - val_loss: 0.4266 - val_accuracy: 0.7924 - val_recall: 0.9834 - val_precision: 0.5811 - val_iou: 0.4350 - lr: 0.0010
# Epoch 8/100
# 11/11 [==============================] - 1s 126ms/step - loss: 0.1683 - accuracy: 0.9614 - recall: 0.9500 - precision: 0.9367 - iou: 0.6668 - val_loss: 0.4403 - val_accuracy: 0.7769 - val_recall: 0.9874 - val_precision: 0.5629 - val_iou: 0.4464 - lr: 0.0010
# Epoch 9/100
# 11/11 [==============================] - 1s 121ms/step - loss: 0.1600 - accuracy: 0.9617 - recall: 0.9575 - precision: 0.9311 - iou: 0.6840 - val_loss: 0.4124 - val_accuracy: 0.7895 - val_recall: 0.9713 - val_precision: 0.5788 - val_iou: 0.4690 - lr: 0.0010
# Epoch 10/100
# 11/11 [==============================] - 1s 124ms/step - loss: 0.1559 - accuracy: 0.9602 - recall: 0.9483 - precision: 0.9348 - iou: 0.6947 - val_loss: 0.4642 - val_accuracy: 0.7617 - val_recall: 0.9772 - val_precision: 0.5469 - val_iou: 0.4717 - lr: 0.0010
# Epoch 11/100
# 11/11 [==============================] - 1s 128ms/step - loss: 0.1559 - accuracy: 0.9567 - recall: 0.9549 - precision: 0.9199 - iou: 0.7044 - val_loss: 0.3222 - val_accuracy: 0.8476 - val_recall: 0.9791 - val_precision: 0.6569 - val_iou: 0.5441 - lr: 0.0010
# Epoch 12/100
# 11/11 [==============================] - 1s 125ms/step - loss: 0.1410 - accuracy: 0.9630 - recall: 0.9605 - precision: 0.9321 - iou: 0.7221 - val_loss: 0.2415 - val_accuracy: 0.9098 - val_recall: 0.9780 - val_precision: 0.7694 - val_iou: 0.5746 - lr: 0.0010
# Epoch 13/100
# 11/11 [==============================] - 1s 125ms/step - loss: 0.1386 - accuracy: 0.9625 - recall: 0.9534 - precision: 0.9365 - iou: 0.7323 - val_loss: 0.2773 - val_accuracy: 0.8754 - val_recall: 0.9546 - val_precision: 0.7100 - val_iou: 0.5692 - lr: 0.0010
# Epoch 14/100
# 11/11 [==============================] - 1s 125ms/step - loss: 0.1273 - accuracy: 0.9672 - recall: 0.9582 - precision: 0.9454 - iou: 0.7479 - val_loss: 0.2696 - val_accuracy: 0.8745 - val_recall: 0.9580 - val_precision: 0.7073 - val_iou: 0.5688 - lr: 0.0010
# Epoch 15/100
# 11/11 [==============================] - 1s 130ms/step - loss: 0.1221 - accuracy: 0.9679 - recall: 0.9601 - precision: 0.9458 - iou: 0.7621 - val_loss: 0.2893 - val_accuracy: 0.8611 - val_recall: 0.9634 - val_precision: 0.6823 - val_iou: 0.5675 - lr: 0.0010
# Epoch 16/100
# 11/11 [==============================] - 1s 123ms/step - loss: 0.1143 - accuracy: 0.9698 - recall: 0.9629 - precision: 0.9484 - iou: 0.7736 - val_loss: 0.2440 - val_accuracy: 0.8880 - val_recall: 0.9602 - val_precision: 0.7320 - val_iou: 0.6107 - lr: 0.0010
# Epoch 17/100
# 11/11 [==============================] - 1s 124ms/step - loss: 0.1078 - accuracy: 0.9722 - recall: 0.9630 - precision: 0.9551 - iou: 0.7832 - val_loss: 0.2217 - val_accuracy: 0.9008 - val_recall: 0.9526 - val_precision: 0.7610 - val_iou: 0.6227 - lr: 1.0000e-04
# Epoch 18/100
# 11/11 [==============================] - 1s 121ms/step - loss: 0.1021 - accuracy: 0.9752 - recall: 0.9659 - precision: 0.9609 - iou: 0.7887 - val_loss: 0.2000 - val_accuracy: 0.9156 - val_recall: 0.9453 - val_precision: 0.7974 - val_iou: 0.6346 - lr: 1.0000e-04
# Epoch 19/100
# 11/11 [==============================] - 1s 123ms/step - loss: 0.0998 - accuracy: 0.9762 - recall: 0.9694 - precision: 0.9604 - iou: 0.7925 - val_loss: 0.1922 - val_accuracy: 0.9204 - val_recall: 0.9438 - val_precision: 0.8098 - val_iou: 0.6411 - lr: 1.0000e-04
# Epoch 20/100
# 11/11 [==============================] - 1s 126ms/step - loss: 0.0975 - accuracy: 0.9771 - recall: 0.9699 - precision: 0.9626 - iou: 0.7961 - val_loss: 0.1859 - val_accuracy: 0.9235 - val_recall: 0.9406 - val_precision: 0.8191 - val_iou: 0.6462 - lr: 1.0000e-04
# Epoch 21/100
# 11/11 [==============================] - 1s 123ms/step - loss: 0.0956 - accuracy: 0.9779 - recall: 0.9706 - precision: 0.9643 - iou: 0.7988 - val_loss: 0.1790 - val_accuracy: 0.9277 - val_recall: 0.9381 - val_precision: 0.8311 - val_iou: 0.6527 - lr: 1.0000e-04
# Epoch 22/100
# 11/11 [==============================] - 1s 125ms/step - loss: 0.0936 - accuracy: 0.9788 - recall: 0.9718 - precision: 0.9655 - iou: 0.8018 - val_loss: 0.1721 - val_accuracy: 0.9330 - val_recall: 0.9345 - val_precision: 0.8472 - val_iou: 0.6600 - lr: 1.0000e-04
# Epoch 23/100
# 11/11 [==============================] - 1s 132ms/step - loss: 0.0916 - accuracy: 0.9796 - recall: 0.9725 - precision: 0.9672 - iou: 0.8047 - val_loss: 0.1677 - val_accuracy: 0.9365 - val_recall: 0.9315 - val_precision: 0.8586 - val_iou: 0.6655 - lr: 1.0000e-04
# Epoch 24/100
# 11/11 [==============================] - 2s 136ms/step - loss: 0.0896 - accuracy: 0.9803 - recall: 0.9735 - precision: 0.9684 - iou: 0.8076 - val_loss: 0.1631 - val_accuracy: 0.9398 - val_recall: 0.9273 - val_precision: 0.8709 - val_iou: 0.6719 - lr: 1.0000e-04
# Epoch 25/100
# 11/11 [==============================] - 1s 129ms/step - loss: 0.0876 - accuracy: 0.9811 - recall: 0.9742 - precision: 0.9699 - iou: 0.8105 - val_loss: 0.1587 - val_accuracy: 0.9429 - val_recall: 0.9230 - val_precision: 0.8830 - val_iou: 0.6790 - lr: 1.0000e-04
# Epoch 26/100
# 11/11 [==============================] - 1s 126ms/step - loss: 0.0856 - accuracy: 0.9819 - recall: 0.9750 - precision: 0.9716 - iou: 0.8136 - val_loss: 0.1555 - val_accuracy: 0.9452 - val_recall: 0.9184 - val_precision: 0.8932 - val_iou: 0.6856 - lr: 1.0000e-04
# Epoch 27/100
# 11/11 [==============================] - 1s 130ms/step - loss: 0.0836 - accuracy: 0.9827 - recall: 0.9759 - precision: 0.9729 - iou: 0.8165 - val_loss: 0.1530 - val_accuracy: 0.9466 - val_recall: 0.9144 - val_precision: 0.9007 - val_iou: 0.6916 - lr: 1.0000e-04
# Epoch 28/100
# 11/11 [==============================] - 1s 123ms/step - loss: 0.0816 - accuracy: 0.9835 - recall: 0.9770 - precision: 0.9743 - iou: 0.8194 - val_loss: 0.1515 - val_accuracy: 0.9477 - val_recall: 0.9095 - val_precision: 0.9081 - val_iou: 0.6972 - lr: 1.0000e-04
# Epoch 29/100
# 11/11 [==============================] - 1s 125ms/step - loss: 0.0799 - accuracy: 0.9841 - recall: 0.9778 - precision: 0.9753 - iou: 0.8222 - val_loss: 0.1506 - val_accuracy: 0.9487 - val_recall: 0.9058 - val_precision: 0.9143 - val_iou: 0.7013 - lr: 1.0000e-04
# Epoch 30/100
# 11/11 [==============================] - 1s 125ms/step - loss: 0.0787 - accuracy: 0.9845 - recall: 0.9785 - precision: 0.9758 - iou: 0.8244 - val_loss: 0.1519 - val_accuracy: 0.9485 - val_recall: 0.9050 - val_precision: 0.9143 - val_iou: 0.7033 - lr: 1.0000e-04
# Epoch 31/100
# 11/11 [==============================] - 1s 120ms/step - loss: 0.0781 - accuracy: 0.9844 - recall: 0.9792 - precision: 0.9747 - iou: 0.8258 - val_loss: 0.1515 - val_accuracy: 0.9492 - val_recall: 0.8993 - val_precision: 0.9214 - val_iou: 0.7068 - lr: 1.0000e-04
# Epoch 32/100
# 11/11 [==============================] - 1s 122ms/step - loss: 0.0775 - accuracy: 0.9846 - recall: 0.9787 - precision: 0.9757 - iou: 0.8273 - val_loss: 0.1490 - val_accuracy: 0.9502 - val_recall: 0.9060 - val_precision: 0.9189 - val_iou: 0.7137 - lr: 1.0000e-04
# Epoch 33/100
# 11/11 [==============================] - 1s 122ms/step - loss: 0.0759 - accuracy: 0.9851 - recall: 0.9783 - precision: 0.9777 - iou: 0.8297 - val_loss: 0.1534 - val_accuracy: 0.9494 - val_recall: 0.8855 - val_precision: 0.9344 - val_iou: 0.7133 - lr: 1.0000e-04
# Epoch 34/100
# 11/11 [==============================] - 1s 122ms/step - loss: 0.0751 - accuracy: 0.9853 - recall: 0.9812 - precision: 0.9754 - iou: 0.8311 - val_loss: 0.1466 - val_accuracy: 0.9513 - val_recall: 0.9070 - val_precision: 0.9217 - val_iou: 0.7206 - lr: 1.0000e-04
# Epoch 35/100
# 11/11 [==============================] - 1s 129ms/step - loss: 0.0726 - accuracy: 0.9865 - recall: 0.9809 - precision: 0.9791 - iou: 0.8342 - val_loss: 0.1480 - val_accuracy: 0.9521 - val_recall: 0.8925 - val_precision: 0.9371 - val_iou: 0.7247 - lr: 1.0000e-04
# Epoch 36/100
# 11/11 [==============================] - 1s 119ms/step - loss: 0.0720 - accuracy: 0.9863 - recall: 0.9818 - precision: 0.9779 - iou: 0.8361 - val_loss: 0.1522 - val_accuracy: 0.9498 - val_recall: 0.8948 - val_precision: 0.9272 - val_iou: 0.7190 - lr: 1.0000e-04
# Epoch 37/100
# 11/11 [==============================] - 1s 123ms/step - loss: 0.0705 - accuracy: 0.9871 - recall: 0.9828 - precision: 0.9791 - iou: 0.8379 - val_loss: 0.1481 - val_accuracy: 0.9515 - val_recall: 0.8990 - val_precision: 0.9294 - val_iou: 0.7249 - lr: 1.0000e-04
# Epoch 38/100
# 11/11 [==============================] - 1s 121ms/step - loss: 0.0705 - accuracy: 0.9868 - recall: 0.9824 - precision: 0.9786 - iou: 0.8395 - val_loss: 0.1542 - val_accuracy: 0.9494 - val_recall: 0.8869 - val_precision: 0.9330 - val_iou: 0.7271 - lr: 1.0000e-04
# Epoch 39/100
# 11/11 [==============================] - 1s 120ms/step - loss: 0.0688 - accuracy: 0.9875 - recall: 0.9822 - precision: 0.9809 - iou: 0.8416 - val_loss: 0.1538 - val_accuracy: 0.9494 - val_recall: 0.8893 - val_precision: 0.9309 - val_iou: 0.7280 - lr: 1.0000e-05
# Epoch 40/100
# 11/11 [==============================] - 1s 120ms/step - loss: 0.0676 - accuracy: 0.9882 - recall: 0.9845 - precision: 0.9808 - iou: 0.8428 - val_loss: 0.1536 - val_accuracy: 0.9495 - val_recall: 0.8920 - val_precision: 0.9286 - val_iou: 0.7287 - lr: 1.0000e-05
# Epoch 41/100
# 11/11 [==============================] - 1s 120ms/step - loss: 0.0670 - accuracy: 0.9886 - recall: 0.9852 - precision: 0.9811 - iou: 0.8434 - val_loss: 0.1556 - val_accuracy: 0.9489 - val_recall: 0.8903 - val_precision: 0.9284 - val_iou: 0.7288 - lr: 1.0000e-05
# Epoch 42/100
# 11/11 [==============================] - 1s 124ms/step - loss: 0.0666 - accuracy: 0.9888 - recall: 0.9848 - precision: 0.9822 - iou: 0.8440 - val_loss: 0.1577 - val_accuracy: 0.9484 - val_recall: 0.8878 - val_precision: 0.9289 - val_iou: 0.7290 - lr: 1.0000e-05
# Epoch 43/100
# 11/11 [==============================] - 1s 130ms/step - loss: 0.0663 - accuracy: 0.9890 - recall: 0.9847 - precision: 0.9826 - iou: 0.8443 - val_loss: 0.1587 - val_accuracy: 0.9481 - val_recall: 0.8871 - val_precision: 0.9284 - val_iou: 0.7298 - lr: 1.0000e-06
# Epoch 44/100
# 11/11 [==============================] - 1s 132ms/step - loss: 0.0663 - accuracy: 0.9890 - recall: 0.9847 - precision: 0.9827 - iou: 0.8443 - val_loss: 0.1597 - val_accuracy: 0.9477 - val_recall: 0.8865 - val_precision: 0.9278 - val_iou: 0.7306 - lr: 1.0000e-06

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(44)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
import os
import numpy as np
import cv2
import tensorflow as tf
from tensorflow.keras.utils import CustomObjectScope
from tqdm import tqdm

# %%
def mask_parse(mask):
    mask = np.squeeze(mask)
    mask = [mask, mask, mask]
    mask = np.transpose(mask, (1, 2, 0))
    return mask

# %%
model.save("unet_test2.h5")

# %%
batch_size = 32
test_dataset = tf_dataset(test_x, test_y, batch=batch_size)
 
test_steps = (len(test_x)//batch_size)
if len(test_x) % batch_size != 0:
    test_steps += 1

# %%
model.evaluate(test_dataset, steps=test_steps)
# Out:
# 2/2 [==============================] - 1s 142ms/step - loss: 0.4635 - accuracy: 0.8718 - recall: 0.9909 - precision: 0.6960 - iou: 0.4603
# [0.46349334716796875,
#  0.8717753291130066,
#  0.9908581972122192,
#  0.6959728002548218,
#  0.4603223502635956]

# %%
def read_image2(path):
    #path = path.decode()
    x = gdal.Open(path).ReadAsArray()
    #x = np.rollaxis(x, 0, 2)
    x = np.expand_dims(x,axis=-1)
    #x = x/65535
    x = x.astype(np.float32)
    return x


def read_mask2(path):
    #path = path.decode()
    x = gdal.Open(path).ReadAsArray()
    #x = np.rollaxis(x, 0, 2)
    x = np.expand_dims(x, axis=-1)
    x = x.astype(np.float32)
    return x

# %%
for i, (x, y) in tqdm(enumerate(zip(test_x, test_y)), total=len(test_x)):
    x = read_image2(x)
    y = read_mask2(y)
    y_pred = model.predict(np.expand_dims(x, axis=-1))[0] > 0.9
    h, w, _ = x.shape
    white_line = np.ones((h, 10, 3)) * 255.0
    all_images = [
        x * 255.0, white_line,
        mask_parse(y_pred) * 255.0
    ]
    image = np.concatenate(all_images, axis=1)
    cv2.imwrite(f"results/{i}.png", image)
# Out:
#   0%|                                                                                           | 0/42 [00:00<?, ?it/s]
# (5, 128, 128, 1)
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In [79], line 4
#       2 x = read_image2(x)
#       3 y = read_mask2(y)
# ----> 4 y_pred = model.predict(np.expand_dims(x, axis=-1))[0] > 0.9
#       5 h, w, _ = x.shape
#       6 white_line = np.ones((h, 10, 3)) * 255.0
#
# File ~\anaconda3\envs\unet\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\envs\unet\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# transpose expects a vector of size 5. But input(1) is a vector of size 4
# 	 [[{{node model/conv2d/Conv2D-0-TransposeNHWCToNCHW-LayoutOptimizer}}]] [Op:__inference_predict_function_15160]

# %%
import os, os.path
imgs = []
path2 = "F:\\Citra\\UNet\\Test"
valid_images = [".tif"]
for f in os.listdir(path2):
    ext = os.path.splitext(f)[1]
    if ext.lower() not in valid_images:
        continue
    imgs.append(os.path.join(path2,f))
imgs
# Out:
# ['F:\\Citra\\UNet\\Test\\1_s22_training__1020_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1021_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1022_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1023_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1024_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1028_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1029_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1030_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1031_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1032_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1033_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1034_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1035_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1036_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1037_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1038_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1039_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1040_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1041_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1042_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1043_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1044_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1045_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1046_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1047_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1048_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1049_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1050_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1051_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1052_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1053_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1054_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1055_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1056_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1057_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1058_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1059_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1060_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1061_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1062_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1092_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1093_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1098_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1099_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1100_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1101_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1102_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1103_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1106_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1107_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1108_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1109_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1110_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1111_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1112_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1113_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1114_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1115_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1116_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1117_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1118_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1119_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1120_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1121_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1122_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1123_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1124_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1125_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1126_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1127_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1128_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1129_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1130_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1131_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1132_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1133_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1168_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1169_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1170_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1171_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1172_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1173_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1177_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1178_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1179_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1180_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1181_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1182_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1183_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1184_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1185_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1186_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1187_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1188_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1189_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1190_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1191_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1192_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1193_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1194_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1195_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1196_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1197_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1198_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1199_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1200_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1201_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1202_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1203_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1204_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1237_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1238_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1239_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1240_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1241_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1242_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1243_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1248_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1249_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1250_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1251_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1252_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1253_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1254_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1255_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1256_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1257_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1258_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1259_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1260_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1261_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1262_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1263_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1264_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1265_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1266_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1267_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1268_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1269_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1270_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1271_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1272_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1273_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1274_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1306_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1307_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1308_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1309_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1310_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1311_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1312_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1320_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1321_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1322_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1323_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1324_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1325_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1326_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1327_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1328_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1329_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1330_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1331_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1332_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1333_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1334_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1335_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1336_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1337_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1338_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1339_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1340_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1341_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1342_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1343_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1344_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1345_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1373_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1374_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1375_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1376_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1377_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1378_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1379_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1380_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1381_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1382_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1383_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1390_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1391_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1392_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1393_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1394_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1395_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1396_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1397_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1398_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1399_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1400_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1401_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1402_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1403_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1404_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1405_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1406_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1407_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1408_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1409_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1410_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1411_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1412_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1413_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1414_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1415_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1416_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1444_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1445_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1446_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1447_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1449_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1450_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1451_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1452_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1455_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1458_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1459_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1460_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1461_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1462_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1463_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1464_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1465_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1466_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1467_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1468_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1469_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1470_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1471_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1472_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1473_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1474_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1475_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1476_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1477_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1478_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1479_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1480_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1481_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1482_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1483_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1484_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1485_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1486_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1515_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1516_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1520_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1521_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1522_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1523_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1530_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1531_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1532_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1533_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1534_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1535_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1536_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1537_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1538_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1539_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1540_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1541_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1542_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1543_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1544_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1545_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1546_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1547_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1548_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1549_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1550_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1551_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1552_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1553_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1554_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1555_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1556_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1557_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1585_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1586_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1587_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1588_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1589_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1590_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1591_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1592_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1593_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1602_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1603_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1604_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1605_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1606_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1607_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1608_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1609_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1610_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1611_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1612_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1613_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1614_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1615_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1616_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1617_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1618_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1619_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1620_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1621_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1622_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1623_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1624_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1625_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1626_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1627_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1628_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1657_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1658_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1659_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1660_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1661_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1662_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1663_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1664_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__166_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1672_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1673_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1674_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1675_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1676_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1677_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1678_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1679_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__167_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1680_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1681_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1682_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1683_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1684_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1685_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1686_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1687_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1688_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1689_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__168_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1690_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1691_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1692_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1693_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1694_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1695_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1696_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1697_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1698_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1699_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__169_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__170_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1728_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1729_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1730_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1731_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1732_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1733_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1734_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1735_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1743_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1744_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1745_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1746_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1747_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1748_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1749_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1750_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1751_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1752_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1753_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1754_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1755_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1756_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1757_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1758_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1759_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1760_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1761_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1762_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1763_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1764_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1765_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1766_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1767_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1768_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1769_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1770_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1798_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1799_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1800_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1801_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1802_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1803_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1804_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1805_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1806_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1807_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1812_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1813_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1814_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1815_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1816_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1817_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1818_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1819_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1820_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1821_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1822_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1823_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1824_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1825_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1826_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1827_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1828_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1829_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1830_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1831_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1832_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1833_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1834_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1835_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1836_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1837_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1838_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1839_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1840_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1841_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1870_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1871_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1872_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1875_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1876_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1877_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1878_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1879_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1883_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1884_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1885_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1886_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1887_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1888_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1889_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1890_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1891_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1892_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1893_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1894_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1895_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1896_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1897_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1898_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1899_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1900_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1901_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1902_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1903_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1904_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1905_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1906_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1907_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1908_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1909_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1910_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1911_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1912_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1941_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1942_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1943_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1945_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1946_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1947_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1948_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1949_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1954_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1955_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1956_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1957_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1958_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1959_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1960_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1961_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1962_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1963_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1964_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1965_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1966_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1967_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1968_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1969_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1970_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1971_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1972_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1973_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1974_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1975_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1976_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1977_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1978_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1979_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1980_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1981_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__1982_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2012_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2013_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2014_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2015_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2016_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2017_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2018_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2019_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2020_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2025_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2026_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2027_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2028_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2029_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2030_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2031_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2032_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2033_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2034_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2035_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2036_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2037_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2038_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2039_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2040_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2041_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2042_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2043_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2044_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2045_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2046_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2047_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2048_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2049_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2050_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2051_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2052_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2053_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2075_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2083_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2084_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2086_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2087_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2088_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2089_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2090_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2096_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2097_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2098_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2099_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2100_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2101_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2102_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2103_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2104_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2105_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2106_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2107_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2108_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2109_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2110_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2111_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2112_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2113_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2114_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2115_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2116_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2117_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2118_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2119_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2120_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2121_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2122_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2123_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2124_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2146_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2147_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2148_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2154_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2155_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2158_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2159_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2160_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2161_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2165_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2166_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2167_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2168_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2169_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2170_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2171_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2172_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2173_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2174_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2175_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2176_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2177_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2178_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2179_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2180_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2181_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2182_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2183_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2184_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2185_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2186_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2187_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2188_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2189_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2190_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2191_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2192_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2193_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2194_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2195_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2217_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2218_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2219_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2230_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2231_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2237_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2238_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2239_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2240_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2241_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2242_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2243_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2244_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2245_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2246_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2247_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2248_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2249_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2250_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2251_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2252_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2253_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2254_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2255_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2256_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2257_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2258_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2259_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2260_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2261_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2262_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2263_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2264_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2265_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2288_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2289_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2290_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2301_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2302_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2308_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2309_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2310_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2311_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2312_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2313_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2314_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2315_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2316_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2317_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2318_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2319_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2320_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2321_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2322_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2323_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2324_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2325_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2326_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2327_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2328_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2329_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2330_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2331_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2332_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2333_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2334_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2335_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2336_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2358_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2359_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2360_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__236_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2373_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__237_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2380_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2381_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2382_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2383_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2384_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2385_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2386_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2387_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2388_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2389_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__238_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2390_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2391_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2392_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2393_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2394_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2395_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2396_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2397_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2398_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2399_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__239_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2400_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2401_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2402_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2403_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2404_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2405_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2406_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2407_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__240_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__241_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2429_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__242_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__243_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__244_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2450_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2451_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2452_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2453_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2454_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2455_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2456_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2457_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2458_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2459_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__245_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2460_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2461_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2462_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2463_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2464_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2465_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2466_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2467_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2468_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2469_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__246_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2470_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2471_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2472_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2473_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2474_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2475_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2476_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2477_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2478_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2516_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2520_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2521_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2522_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2523_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2524_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2525_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2526_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2527_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2528_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2529_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2530_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2531_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2532_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2533_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2534_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2535_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2536_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2537_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2538_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2539_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2540_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2541_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2542_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2543_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2544_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2545_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2546_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2547_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2548_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2549_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2591_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2592_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2593_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2594_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2595_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2596_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2597_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2598_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2599_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2600_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2601_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2602_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2603_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2604_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2605_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2606_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2607_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2608_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2609_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2610_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2611_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2612_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2613_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2614_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2615_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2616_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2617_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2618_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2619_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2659_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2660_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2661_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2662_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2663_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2664_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2665_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2666_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2667_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2668_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2669_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2670_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2671_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2672_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2673_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2674_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2675_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2676_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2677_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2678_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2679_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2680_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2681_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2682_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2683_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2684_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2685_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2686_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2687_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2688_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2689_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2690_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2721_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2722_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2723_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2729_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2730_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2731_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2732_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2733_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2734_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2735_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2736_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2737_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2738_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2739_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2740_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2741_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2742_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2743_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2744_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2745_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2746_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2747_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2748_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2749_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2750_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2751_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2752_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2753_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2754_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2755_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2756_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2757_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2758_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2759_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2760_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2761_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2792_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2793_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2794_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2799_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2800_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2801_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2802_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2803_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2804_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2805_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2806_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2807_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2808_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2809_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2810_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2811_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2812_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2813_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2814_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2815_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2816_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2817_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2818_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2819_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2820_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2821_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2822_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2823_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2824_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2825_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2826_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2827_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2828_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2829_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2830_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2831_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2832_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2864_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2865_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2866_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2867_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2868_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2869_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2870_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2871_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2872_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2873_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2874_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2875_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2876_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2877_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2878_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2879_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2880_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2881_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2882_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2883_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2884_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2885_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2886_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2887_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2888_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2889_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2890_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2891_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2892_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2893_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2894_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2895_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2896_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2897_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2898_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2899_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2900_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2901_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2902_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2935_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2936_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2937_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2939_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2940_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2941_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2942_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2943_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2944_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2945_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2946_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2947_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2948_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2949_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2950_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2951_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2952_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2953_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2954_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2955_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2956_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2957_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2958_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2959_128.tif',
#  'F:\\Citra\\UNet\\Test\\1_s22_training__2960_128.tif',
#  ...]

# %%
path3 = "I:\\UNet\\Tiles_NDVI\\Merge\\NG04"
model = keras.models.load_model("unet_deforestation.h5")
for k in tqdm(imgs):
    test = read_image2(k)
    name = k.split ("\\") [- 1] .split (".") [0]
    y_pred = model.predict(np.expand_dims(test, axis=1))[0] > 0.90
    h, w, _ = test.shape
    white_line = np.ones((h, 10, 3)) * 255.0
    all_images = y_pred * 255.0
    #all_images = [
        #mask_parse(y_pred) * 255.0
    #]
    image = np.concatenate(all_images, axis=1)
    cv2.imwrite(os.path.join(path3, f"{name}_ps.png"), image)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 4517/4517 [03:25<00:00, 21.95it/s]

# %%
import imutils
import cv2
import numpy as np
from tensorflow.keras.utils import normalize
from matplotlib import pyplot as plt

# %%
def prediction(model, image, patch_size):
    segm_img = np.zeros(image.shape[:2])  #Array with zeros to be filled with segmented values
    patch_num=1
    for i in range(0, image.shape[0], 128):   #Steps of 256
        for j in range(0, image.shape[1], 128):  #Steps of 256
            #print(i, j)
            single_patch = image[i:i+patch_size, j:j+patch_size]
            single_patch = np.array(single_patch)
            if single_patch.shape[1] != 128 or single_patch.shape[1] != 128:
                pass
                #single_patch = single_patch.resize(128, 128)
                #single_patch[np.isnan(single_patch)] = 0
                #single_patch_norm = np.expand_dims(single_patch, axis=-1)
                #single_patch_shape = single_patch_norm.shape[:2]
                #single_patch_input = (np.expand_dims(single_patch_norm, 0))/65535
                #single_patch_prediction = (model.predict(single_patch_input)[0,:,:,0] > 0.5).astype(np.uint8)
                #segm_img[i:i+single_patch_shape[0], j:j+single_patch_shape[1]] += cv2.resize(single_patch_prediction, single_patch_shape[::-1])
          
                #print("Finished processing patch number ", patch_num, " at position ", i,j)
                #patch_num+=1
            else:
                single_patch_norm = np.expand_dims(single_patch, axis=-1)
                single_patch_shape = single_patch_norm.shape[:2]
                single_patch_input = (np.expand_dims(single_patch_norm, 0))/65535
                single_patch_prediction = (model.predict(single_patch_input)[0,:,:,0] > 0.5).astype(np.uint8)
                segm_img[i:i+single_patch_shape[0], j:j+single_patch_shape[1]] += cv2.resize(single_patch_prediction, single_patch_shape[::-1])
          
                print("Finished processing patch number ", patch_num, " at position ", i,j)
                patch_num+=1
        return segm_img

# %%
from osgeo import gdal
patch_size = 128
large_image = gdal.Open('data/CAPELLA_C02_SP_GEO_REPRO_HH_20210113201240_20210113201307.tif').ReadAsArray()
#large_image[np.isnan(large_image)] = 0
print(large_image.shape)
print(np.expand_dims(np.array(large_image), axis=-1).shape)
segmented_image = prediction(model, large_image, patch_size)

# %%
#plt.hist(segmented_image.flatten())  #Threshold everything above 0

plt.imsave('data/segm.jpg', segmented_image, cmap='gray')
